# %% [markdown]
# # Python 3
# ## [파이썬 강의에 앞서](chapter_1/chapter_1_pre_lecture.ipynb/#goal)
# * [코드 편집기 'Sublime Text 3'](chapter_1_sublimetext.ipynb)
# * [강의 정리 노트 'Evernote'](chapter_1_evernote.ipynb)
#
# ## 파이썬 기초 속성
# ### 파이썬 문과 기본 자료형
# * 변수 이름 짓기
# * [파이썬 기초문](chapter_2/chapter_2_python_basic.ipynb/#ext)
# * 콘솔 입·출력
# * 자료형의 종류
# * 변경 가능성
# * 메모리 관리
# * 파이썬 제어문
# * 함수
# * 클래스
#
# ### 수치
# * 수치 자료형
# * 수치 연산자
# * 수치 연산 함수
#
# ### 문자열
# * 시퀀스 자료형
# * 문자열 정의하기
# * 문자열의 서식 지정하기
# * 문자열 메서드
# * 유니코드 문자열과 바이트
# * 문서 문자열
#
# ### 리스트
# * 리스트의 연산
# * 중첩 리스트
# * 리스트 메서드
# * 리스트에 튜플이나 리스트가 있을 때 반복 참조하기
# * 리스트 정렬하기
# * 리스트 내장
# * 순환 참조 리스트
# * 순차적인 정수 리스트 만들기
# * 지역적으로 사용 가능한 이름 리스트 얻기
# * 명령줄 인수 처리
# * 디렉터리의 파일 목록 얻기
#
# ### 튜플
# * 튜플의 연산
# * 패킹과 언패킹
# * 리스트와의 차이점
# * 이름 있는 튜플
#
# ### 사전
# * 사전의 연산
# * 사전의 뷰
# * 사전의 메서드
# * 사전의 내장
# * 심볼 테이블
# * 이름 공간 구현하기
# * 순서를 유지하는 사전
#
# ### 객체의 복사와 형 변환
# * 객체의 복사
# * 얕은 복사와 깊은 복사
# * 형 변환
# * 파이썬 자료형의 이진 변환
# * 파이썬 데이터를 바이트 열로 변환
# * 바이트 저장 순서
# * 정렬 문제
#
#
# ### 집합
# * set 객체의 생성
# * set 객체의 연산
# * frozenset 객체의 생성과 연산
# * 집합 내장
#
# ### 파일
# * 텍스트 파일 쓰기·읽기
# * 줄 단위로 파일 쓰기·읽기
# * 파일에서 원하는 만큼 문자 읽기
# * 이진 파일 쓰기·읽기
# * 파일 처리 모드
# * 임의 접근 파일
# * 파일 객체의 메서드와 속성
#
# ### 함수
# * 함수의 정의
# * 함수의 호출
# * 유효 범위
# * 함수의 인수
# * 함수 안의 함수
# * 한 줄짜리 함수 - 람다 함수
# * 함수적 프로그래밍
# * 함수 객체의 속성
# * 재귀적 프로그래밍
#
# ### 모듈과 패키지
# * 모듈
# * 패키지
# * 프로그램 배포하기
#
# ### 클래스
# * 파이썬 클래스란
# * 클래스 정의와 인스턴스 객체의 생성
# * 메서드의 정의와 호출
# * 클래스 멤버와 인스턴스 멤버
#
# ### 연산자의 중복과 장식자
# * 연산자의 중복
# * 장식자
# * 정적 메서드와 클래스 메서드
# * property 속성 만들기
#
# ### 상속
# * 상속
# * 다형성
# * 캡슐화
# * 위임
#
# ### 메타클래스
#
# ### 예외처리
# * 예외 처리란
# * try ~ except ~ else 문을 사용하기
# * try 문에서 finally 절을 사용하기
# * raise 문으로 예외 발생시키기
# * assert 문으로 예외 발생시키기
#
# ### 그 외
# * PEP08
